# %% [markdown]
# <a href="https://colab.research.google.com/github/126-134340/2021_PNUAC_AIData/blob/main/07_codelab3_bs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🏷️ **웹 동작원리**
#
#
# ---
# <img src ='https://drive.google.com/uc?export=view&id=1amZ78fUnfp3o5Q1XVKDG3eAAzKaYlPrp'>
#
# ---

# %% [markdown]
# # Beautiful Soup 모듈
# + HTML 및 XML 문서 를 구문 분석하기 위한 Python 패키지
# + DOM 추출
# + 기본적으로 UTF-8 인코딩 방식이지만 CP949도 지원

# %% [markdown]
# 🏷️ **웹 스크래핑(Web Scraping)과 웹 크롤링(Web Crawling)**
#
#
# ---
# + 웹 스크래핑(Web Scraping) : 웹 사이트 상에서 원하는 정보를 추출하는 기술
# + 웹 크롤링(Web Crawling) : 웹 크롤러(자동화봇)가정해진 규칙에 따라 웹 페이지를 수집해서 각 사이트의 정보를 분류하는 기술
#
#
#
#
# ---

# %% [markdown]
# ## BeautifulSoup 모듈을 활용한 스크래핑

# %% [markdown]
# ### 1. 웹 페이지 가져오기

# %%
#모듈 import 
from urllib.request import urlopen

url = 'https://news.daum.net/ranking/popular'

#웹 페이지 가져오기 
webpage = urlopen(url).read().decode('utf-8')
webpage[:200]
# Out:
# '\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum 뉴스" />'

# %% [markdown]
# ### 2. BeautifulSoup 객체 생성
#
# ```python
# from bs4 import BeautifulSoup as bs
#
# 인스턴스명 = BeautifulSoup(markup, parser)
# ```
# * 첫 번째 인자 : HTML 형식의 문자열
# * 두 번째 인자 : 첫 번째 인자의 문자열을 해석하기 위한 파서
#
#   * **파서(parser) 종류**
#     + html.parser : 파이썬 표준 라이브러리에 포함된 파서로 빠르지만 유연하지 않기 때문에 단순한 HTML문서에 사용
#
#         ```
#         BeautifulSoup(markup, "html.parser")
#         ```
#
#     + lxml : 매우 빠르고 유연하지만 외부 의존
#       - lxml의 HTML 파서
#           ```
#           BeautifulSoup(markup, "lxml")
#           ```
#       - lxml의 XML 파서
#           ```
#           BeautifulSoup(markup, "lxml-xml")
#           ```
#
#     + html5lib : 웹 브라우저와 동일한 방식으로 페이지 구문 분석하는 파서로 매우 느리지만 매우 유연하지만 외부 의존
#         ```
#         BeautifulSoup(markup, "html5lib")
#       ```

# %%
#모듈 import 
from bs4 import BeautifulSoup as bs

#DOM 문서 만들기
html =bs(webpage, 'html.parser')

# %%
type(html)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### 2. **Beautiful Soup 파싱 메소드**
# + 태그명
#   + **.find(태그명)** : 조건에 맞는 태그 1개만 찾음
#   + **.find_all(태그명)** : 조건에 맞는 모든 태그 찾음
# + css선택자
#   + **.select_one(선택자)** : 조건에 맞는 CSS선택자 1개만 찾음
#   + **.select(선택자)** : 조건에 맞는 CSS선택자 찾음

# %% [markdown]
# 🏷️ **HTML과 CSS**
#
#
# ---
#
#
#
# + **HTML(Hyper Text Markup Language)**
#   + 웹페이지 상에서 문단, 제목, 표, 이미지, 동영상 등을 정의하고 웹페이지 내용을 구조화하고 의미를 부여하는 마크업 언어
# + **CSS(Cascading Style Sheet)**
#   + 색상, 레이아웃 및 글꼴등 웹페이지의 디자인 요소를 담당하는 선언형 언어로 스타일 시트(Style Sheet)라고도 하고, HTML로 작성된 웹페이지를 보기 좋게 꾸며주는 스타일 규칙 언어
#
# + 참고 사이트 : <https://www.w3schools.com/>
#
#
# ---

# %% [markdown]
# #mArticle > div.rank_news > ul.list_news2 > li

# %%
#자료 추출하기
lis = html.select('#mArticle > div.rank_news > ul.list_news2 > li')
print(type(lis), ' 요소 수 : ', len(lis))
print(lis[0])
# Out:
# <class 'list'>  요소 수 :  50
# <li data-tiara-layer="news_list" data-tiara-ordnum="1" data-tiara-type="article">
# <div class="rank_num rank_popular">
# <span class="wrap_num">
# <span class="num_rank">
# <span class="num_news num1"></span>
# <span class="screen_out">1</span>
# </span>
# </span>
# </div>
# <a class="link_thumb" href="https://v.daum.net/v/20210713161800990">
# <img alt='"성매매업소 방이 43개, 처음 현장 보니 가슴 먹먹"' aria-hidden="true" class="thumb_g" src="https://img1.daumcdn.net/thumb/S95x77ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202107%2F13%2Fohmynews%2F20210713161806335vori.jpg&amp;scode=media"/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="https://v.daum.net/v/20210713161800990">"성매매업소 방이 43개, 처음 현장 보니 가슴 먹먹"</a>
# <span class="info_news">오마이뉴스</span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                         [윤성효 기자] ▲  창원 마산합포구 서성동 성매매 집결지 최대 업소인 '우정집' 실내.    ⓒ 윤성효            ▲  창원 마산합포구 서성동 성매매 집결지 최대 ...
#                     </span>
# </div>
# </div>
# </li>

# %%
#필요한 자료 만들기
for li in lis :
  title = li.select_one('.cont_thumb > .tit_thumb > a').text.replace('"', '')
  info_news = li.select_one('.cont_thumb > .tit_thumb > .info_news').text
  print(title, ':', info_news)
# Out:
# 성매매업소 방이 43개, 처음 현장 보니 가슴 먹먹 : 오마이뉴스
# 은마아파트 수천만원 인테리어하고 들어간 집주인 '부글부글' : 한국경제
# 55억 '남산 뷰' 이태원집 매입한 박나래..5년간 200억 넘게 벌었다 : 뉴스1
# 일출 보려다 물어뜯길 뻔..성산일출봉까지 점령한 야생들개 : 뉴스1
# 윤석열의 '가족 리스크'..김건희, 이번엔 '공소시효 언급' 자충수 : 시사저널
# 집주인 허락없이 페인트 칠한 세입자의 만행..손배 가능할까 : 동아일보
# 식사 후 하면 건강에 '독' 되는 행동 : 코메디닷컴
# 구미 친모 낳지도, 바꾸지도 않았다..검찰 징역 13년 구형 : 중앙일보
# 친구 언니가 무서웠다..전북에서 찾은 대전 실종 초등생 : 서울신문
# 남아공 폭동에 LG공장 전소·약탈..길도 다닐 수 없는 지경 : 중앙일보
# [영상] 하늘에서 물고기가 비처럼 내려와 무슨 일? : 헤럴드경제
# 전여옥, 위기의 이준석에 뒤에서 칼꽂는 게 정치..성인식 치러 : 머니투데이
# [영상]철학 붕괴 윤희숙 연일 이준석 비판..하태경 자해정치[이슈시개] : 노컷뉴스
# 김의겸 김건희 논문, 본인 재직한 회사 사업계획서 베낀 것 : 연합뉴스
# 화이자 백신 79만9천회분 내일 도착..고3·교직원 접종에 사용 : 연합뉴스
# 이재명, 긴급 기자회견..4차 팬데믹 못막으면 전면봉쇄 불가피 : 아시아경제
# 확진자인데 와서 미안 농담에 카페 영업중단..업무방해 무죄 : 서울신문
# 예견된 일.. 주말 전국 백화점 문 닫고 코로나 검사 해야 : 오마이뉴스
# 울산서 숲체험 유치원생 24명에 '벌떼 습격'..학부모 아이 얼굴 퉁퉁(종합) : 뉴스1
# 중국서 2명 살해한 50대 현지인..34년만에 인천서 검거 : 연합뉴스
# 이 시국에 떼창? 팬들 반발에..백기 든 '미스터트롯' 공연 : 쿠키뉴스
# 대장암 위험 높이는 '의외의 습관' 3가지 : 헬스조선
# 인천 초교 집단감염 델타변이 현실로..확산세 커지나 : 연합뉴스
# 파지값 2만 8천원 때문에.. 김해공항 미화원들 '대기발령' : 노컷뉴스
# 보호아동 종료 시기 18살→24살로 연장..'등 떠민 자립' 늦춘다 : 한겨레
# 중등교원 양성 규모 축소..사범대 나와야 국영수 교사된다(종합) : 연합뉴스
# 습도 높으면 35도서도 치명타..습한 한국 여름 무서운 이유 : 중앙일보
# 청와대 앞에 착륙한 미끼 전투기, 힘을 보여주고 싶었다 : 매일경제
# 폭격 맞은 듯 순식간 '폭삭'..중국 1년만에 또 호텔붕괴 참사(종합) : 연합뉴스
# [영상] 경남 의령서 경비행기 추락..2명 숨져 : KBS
# [김대영의 무기 인사이드] '천조국 최종병기' 대륙간탄도미사일 미니트맨 Ⅲ : 서울신문
# 돼지코 같다 싸늘한 반응..BMW 4시리즈 참혹한 결과 : 한국경제
# '지지율 1위' 여론조사 중단에 윤석열 캠프 외압-언론사 억측에 유감 : 한겨레
# [단독]함바왕, 사기죄 실형에 죽겠다..전자발찌 끊고 잠적 : 중앙일보
# 술집 못가니 호텔서 2차 60대 유명 화가, 20대 갤러리 직원 성폭행 : 뉴스1
# '역시 접종이 답'..5월 60세 이상 확진자 94.7%, '미접종' 또는 '1차 14일 내 확진' : 뉴시스
# 양어장을 탈출한 송어는 뇌가 커진다 : 한겨레
# '노도강' 찾은 윤석열, 잘못된 임대차 3법으로 서민 고통 너무 크다 : 조선비즈
# 지지율 꺾이나?..기세등등하던 尹 캠프 '초비상' : 연합뉴스
# 與, 박형준 '허위사실 공표' 檢 고발.. 朴 전형적 정치공작 : 아이뉴스24
# 제가 가르쳤고 믿고 있는.. 조국, 아내 정경심 징역 7년 구형에 '무죄 추정' 대법 판결 공유 : 세계일보
# [영상] 물에 빠진 초등학생 3명..딸바보 40대 아저씨는 바로 뛰어들었다 : 연합뉴스
# 최저임금 9160원에 노동계 '부글부글'..민주노총은 '총파업' 예고(종합) : 뉴시스
# 대전 실종 10세 여아 찾았다..전북서 발견해 가족에 인계 : 아이뉴스24
# [단독] 검찰, 이성윤·박은정 불기소 처분..한변 항고할 것 : MBN
# 산방산 온천 안 갔다니까..동선 숨긴 코로나 감염 제주 목사부부 '집유' : 뉴스1
# [르포]박효신 '야생화' 트는 헬스장..신규회원 뚝, 축축 처진다 : 머니투데이
# 부산도 위태롭다..유흥시설 넘어 식당·학교 등 전방위 확산(종합) : 연합뉴스
# 지금도 대만이 일본 식민지? 日국방백서에 대만 방위 언급 : 뉴스1
# 배우 윤계상도 수술 받은 '뇌동맥류', 얼마나 무서운 병이길래 : 한국경제

# %% [markdown]
# ## 해결문제
# ---
# 댓글많은 뉴스를 사이트의 제목을 수집해서 AI Cloud의 무료 AI 서비스 중 텍스트 감정 분석 결과를 분석하고 결과를 파일로 저장하시오.단, 감성분석 분석(긍정,중립,부정)은 함수를 이용하여 작성하고 댓글수와 제목의 쉼표는 제거하시오.
#
# 예시)
# news.csv 내용
# ```
# 순위,제목,댓글수,언론사,감성,신뢰도
# 1,故손정민 父 "서울경찰청 정민이와 나를 미워한다",2564,데일리안,부정,0.9970703125
# 2,신고만하면 한국인? "中에 나라 파냐" 국적법 때린 반중정서,2274,중앙일보,부정,0.99755859375
# 3,'잔여 백신' 첫날 젊은층 대거 몰렸다..AZ 부정적 시선 바뀌나,1726,파이낸셜뉴스,부정,0.98974609375
# 4,'도쿄올림픽 지도서 독도 삭제' 요구에 日정부 "수용 불가",1543,연합뉴스,부정,0.9873046875
#
# ...
#
# 47,"손정민 사건 제가 책임지고"..경찰 '김창룡 청장 가짜뉴스' 내사,115,뉴스1,부정,0.9921875
# 48,로또 1등 수령자에 통장 비번 요구·5억 적금 강매한 농협,105,뉴스1,부정,0.99072265625
# 49,'도쿄올림픽 지도서 독도 삭제' 韓요구에 日정부 "수용 불가",97,중앙일보,부정,0.986328125
# 50,올림픽 취소로 日 배상금 떠안나..日언론 "IOC와 불평등 계약",93,뉴스1,부정,0.99609375
#
# ```

# %% [markdown]
# https://news.daum.net/ranking/bestreply

# %%
from urllib.request import urlopen
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs
import json

# %%
def getPage(url) :
  webpage = urlopen(url).read().decode('utf-8')
  return webpage

# %%
def AICloud(msg) :
  url = "http://svc.saltlux.ai:31781"
  headers={"Content-Type": "application/json"}

  apIKey = "b11ea326-1ce6-4242-ae33-93d35dc8520b"
  rqData = {
     "key": apIKey,
      "serviceId": "11987300804",
      "argument": {
         "type": "0",
         "query": msg
      }
  }

  # 요청 객체 생성
  req = Request(url, headers=headers)

  # 전달 데이터 json 형태로 만들기
  jdata = json.dumps(rqData).encode('utf-8')

  # 요청
  response = urlopen(req, jdata)

  # 요청에 대한 응답처리
  resp = response.read().decode('utf-8')
  resp = json.loads(resp)
  label = resp['label']
  score = resp['score']

  # 응답처리 반환
  return label, score

# %%
AICloud('나는 네가 좋다.')
# Out:
# ('긍정', 0.9833984375)

# %%
url = 'https://news.daum.net/ranking/bestreply'

wp = getPage(url)
wp
# Out:
# '\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum 뉴스" />\n<meta property="og:site_name" content="다음뉴스" />\n<meta property="og:title" content="뉴스 랭킹"/>\n<meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="다음뉴스" />\n<meta property="og:url" content="https://news.daum.net/ranking/bestreply" />\n<link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<title>뉴스 랭킹 | 다음뉴스</title>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/7031c97/common.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/7031c97/news.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/7031c97/calendar.css.merged.css" />\n\n<!--[if lte IE 8]>\n<script src="https://m2.daumcdn.net/svc/original/U0301/cssjs/JSON-js/fc535e9cc8/json2.min.js"></script>\n<![endif]-->\n<!--[if lt IE 9]>\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/7031c97/ie8.css.merged.css" />\n<![endif]-->\n\n<script src="//t1.daumcdn.net/media/kraken/news/7031c97/common.merged.js"></script>\n\n<script type="text/javascript" src="https://t1.daumcdn.net/tiara/js/v1/tiara.min.js"></script>\n\n<script>\n  var ENV = {\n    Profile: {\n      isProduction: \'true\' || false,\n      isSandbox: \'\' || false,\n      isCbt: \'\' || false,\n    }\n  }\n</script>\n        <script src="//t1.daumcdn.net/media/kraken/news/7031c97/rankingMain.merged.js"></script>\n</head>\n<body class="bg_news">\n<div id="kakaoIndex">\n    <a href="#kakaoBody">본문 바로가기</a>\n    <a href="#kakaoGnb">메뉴 바로가기</a>\n</div>\n\n<div id="kakaoWrap" class="news_type1">\n<div id="wrapMinidaum"></div>\n<script type="text/javascript">\n\tvar minidaum_options = {\n\t\tbgType\t\t\t\t: "white",\n\t\tenableLogoutRetun\t: true,\n\t\tdisableTracker\t\t: true, // false일 경우 사용, true일 경우 미사용\n\t\tenableShield\t\t: false\n\t};\n</script>\n<script src="https://go.daum.net/minidaum_pc.daum"></script>\n\n<div id="kakaoHead" role="banner">\n\t<div class="head_media">\n\t\t<h1>\n\t\t\t<a href="https://news.daum.net/" id="kakaoServiceLogo" data-tiara-layer="GNB default service_news"><span class="ir_wa">뉴스</span></a>\n\t\t</h1>\n\t\t<strong class="screen_out">관련서비스</strong>\n\t\t<ul id="kakaoRelServices" data-tiara-layer="GNB default">\n\t\t\t<li><a href="https://entertain.daum.net" class="link_services link_services1" data-tiara-layer="service_enter"><span class="ir_wa">연예</span></a></li>\n\t\t\t<li><a href="https://sports.daum.net" class="link_services link_services2" data-tiara-layer="service_sports"><span class="ir_wa">스포츠</span></a></li>\n\t\t</ul>\n<h2 class="screen_out">검색</h2>\n<div class="search_news" id="search_news">\n\t<form id="kakaoSearch" name="kakaoSearch" action="//search.daum.net/search" method="get">\n\t\t<fieldset class="fld_inside">\n\t\t\t<legend class="screen_out">검색어 입력폼</legend>\n\t\t\t<div class="box_searchbar">\n\t\t\t\t<label for="qVal" class="lab_search">통합검색</label>\n\t\t\t\t<input type="hidden" name="DA" value="23A" />\n\t\t\t\t<input type="hidden" name="rtmaxcoll" value="NNS">\n\t\t\t\t<input type="text" class="tf_keyword" id="qVal" name="q" value="" title="검색어 입력" autocomplete="off" spellcheck="false">\n\t\t\t\t<button id="kakaoBtnSearch" class="btn_search" type="submit"><span class="ir_wa">검색</span></button>\n\t\t\t</div>\n\t\t</fieldset>\n\t\t<div id="wrap_suggestBox" class="wrap_suggestBox">\n\t\t\t<div id="suggestBox" class="suggestBox box_sub">\n\t\t\t\t<div class="baseBox bg" style="display: none"></div>\n\t\t\t</div>\n\t\t</div>\n\t</form>\n</div>\n<script type="text/javascript" src="https://search1.daumcdn.net/search/suggest_pc/ ...

# %%
html = bs(wp, 'html.parser')

# %% [markdown]
# #mArticle > div.rank_news > ul.list_news2

# %%
lis = html.select('#mArticle > div.rank_news > ul.list_news2 > li')
lis[0]
# Out:
# <li data-tiara-layer="news_list" data-tiara-ordnum="1" data-tiara-type="article">
# <div class="rank_num ">
# <span class="wrap_num">
# <span class="num_rank">
# <span class="num_news num1"></span>
# <span class="screen_out">1</span>
# </span>
# </span>
# <span class="info_rank">
# <span class="screen_out">댓글수</span>
# <span class="ico_news2">4,404</span>
# </span>
# </div>
# <a class="link_thumb" href="https://news.v.daum.net/v/20210713140143407">
# <img alt='이재명, 긴급 기자회견.."4차 팬데믹 못막으면 전면봉쇄 불가피"' aria-hidden="true" class="thumb_g" src="https://img1.daumcdn.net/thumb/S95x77ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202107%2F13%2Fakn%2F20210713140145046mxlh.jpg&amp;scode=media"/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="https://news.v.daum.net/v/20210713140143407">이재명, 긴급 기자회견.."4차 팬데믹 못막으면 전면봉쇄 불가피"</a>
# <span class="info_news">아시아경제</span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                         [아시아경제(수원)=이영규 기자] 이재명 경기도지사가 코로나19 '4차 대확산'(팬데믹)이 시작됐다며 도민들에게 철저한 방역수칙 준수를 호소했다. 이를 막지 못할 경우...
#                     </span>
# </div>
# </div>
# </li>

# %%
lis[0].select_one('.screen_out').text
# Out:
# '1'

# %%
lis[0].select_one('.ico_news2').text.replace(',', '')
# Out:
# '5944'

# %%
lis[0].select_one('.cont_thumb > .tit_thumb > a').text
# Out:
# '윤석열 제친 이낙연..野 대선주자 양자대결서 우세, 이재명보다 경쟁력'

# %%
lis[0].select_one('.info_news').text
# Out:
# '아시아경제'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open('/content/drive/MyDrive/2021_PNUAC_AIData/Data/news.csv', 'w') as fp :
  linehead = '순위,제목,댓글수,언론사,감성,신뢰도\n'
  fp.write(linehead)
  for li in lis :
    rank = li.select_one('.screen_out').text
    title = li.select_one('.tit_thumb > a').text.replace('"', '')
    cnt = li.select_one('.ico_news2').text.replace(',', '')
    news = li.select_one('.info_news').text

    aicloud = AICloud(title)
    #aicloud = ('부정', '0.9')
    line = f'{rank},{title},{cnt},{news},{aicloud[0]},{aicloud[1]}\n'

    print(line)
    fp.write(line)
# Out:
# 1,이재명, 긴급 기자회견..4차 팬데믹 못막으면 전면봉쇄 불가피,4404,아시아경제,부정,0.9931640625
#
# 2,윤석열의 '가족 리스크'..김건희, 이번엔 '공소시효 언급' 자충수,2490,시사저널,부정,0.99560546875
#
# 3,[영상]철학 붕괴 윤희숙 연일 이준석 비판..하태경 자해정치[이슈시개],2215,노컷뉴스,부정,0.99560546875
#
# 4,일출 보려다 물어뜯길 뻔..성산일출봉까지 점령한 야생들개,1477,뉴스1,부정,0.9951171875
#
# 5,'노도강' 찾은 윤석열, 잘못된 임대차 3법으로 서민 고통 너무 크다,1396,조선비즈,부정,0.9970703125
#
# 6,성매매업소 방이 43개, 처음 현장 보니 가슴 먹먹,1375,오마이뉴스,부정,0.9873046875
#
# 7,이 시국에 떼창? 팬들 반발에..백기 든 '미스터트롯' 공연,1372,쿠키뉴스,부정,0.99169921875
#
# 8,전여옥, 위기의 이준석에 뒤에서 칼꽂는 게 정치..성인식 치러,1366,머니투데이,부정,0.98974609375
#
# 9,김의겸 김건희 논문, 본인 재직한 회사 사업계획서 베낀 것,1200,연합뉴스,부정,0.99609375
#
# 10,55억 '남산 뷰' 이태원집 매입한 박나래..5년간 200억 넘게 벌었다,1103,뉴스1,긍정,0.450927734375
#
# 11,제가 가르쳤고 믿고 있는.. 조국, 아내 정경심 징역 7년 구형에 '무죄 추정' 대법 판결 공유,1046,세계일보,부정,0.97705078125
#
# 12,은마아파트 수천만원 인테리어하고 들어간 집주인 '부글부글',935,한국경제,부정,0.9482421875
#
# 13,與, 박형준 '허위사실 공표' 檢 고발.. 朴 전형적 정치공작,761,아이뉴스24,부정,0.9970703125
#
# 14,보호아동 종료 시기 18살→24살로 연장..'등 떠민 자립' 늦춘다,693,한겨레,부정,0.98828125
#
# 15,남아공 폭동에 LG공장 전소·약탈..길도 다닐 수 없는 지경,687,중앙일보,부정,0.99560546875
#
# 16,조국 저격한 '무법의 시간' 읽은 금태섭 금기 건드려..일독 권해,680,머니투데이,부정,0.99365234375
#
# 17,지지율 꺾이나?..기세등등하던 尹 캠프 '초비상',611,연합뉴스,부정,0.982421875
#
# 18,'지지율 1위' 여론조사 중단에 윤석열 캠프 외압-언론사 억측에 유감,582,한겨레,부정,0.99658203125
#
# 19,K방역의 민낯.. 주사기·진단키트·선별진료소까지 줄줄이 혼선,576,조선일보,부정,0.99658203125
#
# 20,구미 친모 낳지도, 바꾸지도 않았다..검찰 징역 13년 구형,559,중앙일보,부정,0.99365234375
#
# 21,최저임금 9160원에 노동계 '부글부글'..민주노총은 '총파업' 예고(종합),547,뉴시스,부정,0.9912109375
#
# 22,집주인 허락없이 페인트 칠한 세입자의 만행..손배 가능할까,507,동아일보,부정,0.99755859375
#
# 23,정은경, 방역 실패 사과.. 오세훈 상생방역 4차 원인 아냐, 3분기 3600만명 접종 믿어달라,506,조선비즈,부정,0.98876953125
#
# 24,화이자 백신 79만9천회분 내일 도착..고3·교직원 접종에 사용,467,연합뉴스,중립,0.9580078125
#
# 25,남자 더 뽑으려고 女 점수 낮춘 국민은행, '인사팀장' 항소심서 실형,445,머니투데이,부정,0.99658203125
#
# 26,파지값 2만 8천원 때문에.. 김해공항 미화원들 '대기발령',426,노컷뉴스,부정,0.99462890625
#
# 27,지상욱, 윤호중 '탱자 이준석' 발언에 말조심하라,415,연합뉴스,부정,0.99609375
#
# 28,돼지코 같다 싸늘한 반응..BMW 4시리즈 참혹한 결과,409,한국경제,부정,0.99755859375
#
# 29,중국서 2명 살해한 50대 현지인..34년만에 인천서 검거,382,연합뉴스,부정,0.9794921875
#
# 30,[단독] 검찰, 이성윤·박은정 불기소 처분..한변 항고할 것,257,MBN,부정,0.990234375
#
# 31,식사 후 하면 건강에 '독' 되는 행동,227,코메디닷컴,부정,0.99609375
#
# 32,친구 언니가 무서웠다..전북에서 찾은 대전 실종 초등생,199,서울신문,부정,0.9755859375
#
# 33,[영상] 물에 빠진 초등학생 3명..딸바보 40대 아저씨는 바로 뛰어들었다,179,연합뉴스,부정,0.98779296875
#
# 34,윤석열 제친 이낙연 여론조사.. 어디까지 믿어도 될지,165,쿠키뉴스,부정,0.99365234375
#
# 35,술집 못가니 호텔서 2차 60대 유명 화가, 20대 갤러리 직원 성폭행,154,뉴스1,부정,0.99560546875
#
# 36,박형준, 與 검찰 고발에 불법 사찰 지시한 적 없다,120,아시아경제,부정,0.9931640625
#
# 37,주문 6분 만에 띵동..초유의 쿠팡마트에 편의점 '발칵',116,한국경제,부정,0.97412109375
#
# 38,홍남기 전국민 지원금 동의 못해..민주당과 정면충돌,116,한국경제,부정,0.99609375
#
# 39,박용진 윤석열·최재형 사퇴, 대한민국 기초 흔든 지옥문 연 것,116,뉴스1,부정,0.99267578125
#
# 40,[단독] '김 빠진 사이다'는 잊어라.. 이재명, 최측근 정성호 앞세워 반격 나선다,115,한국일보,부정,0.99462890625
#
# 41,김제동에 7억 퍼주고 수신료 인상? KBS '맹공'하는 국힘,96,중앙일보,부정,0.9921875
#
# 42,[속보] 이동훈 정권사람이 윤석열 치고 자기들 도우면 없던일로 만들어준다고 해..공작이다,93,데일리안,부정,0.998046875
#
# 43,김어준 '대통령의 저주' 安 발언에 오세훈에게도 책임 물어야(종합),88,뉴시스,부정,0.9970703125
#
# 44,숙소까지 어떻게 왔는지 모르겠다..성산일출봉 점령한 들개,86,서울신문,부정,0.9833984375
#
# 45,가수 홍진영 사태 불구 조선대 학위부정 잇따라..비리 불감증 도 넘었다,83,더팩트,부정,0.99267578125
#
# 46,예약중단은 정은경 철저함 때문? 분노한 국민에 기름 부은 해명,77,매일경제,부정,0.9970703125
#
# 47,9160원發 실직 공포 덮친다,73,한국경제,부정,0.99365234375
#
# 48,[1번지현장] 정성호 이재명만이 본선 승리할 후보..선거 전략은?,73,연합뉴스TV,부정,0.67578125
#
# 49,이재명 '국밥'에서 '사이다'로 변하나..첫 이낙연 비판 성명내며 '견제',64,뉴스1,부정,0.99658203125
#
# 50,[속보] 오후 6시까지 1천288명, 어제보다 385명↑..최다 기록 또 깨질듯,61,연합뉴스,부정,0.97802734375

# %% [markdown]
# ---
#
#
# ※ 카카오톡 메신저 내용 분석해보기
#
#
# ---
